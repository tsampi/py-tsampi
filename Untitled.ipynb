# %%
import hashlib
from __future__ import print_function
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib notebook

# %%
hashes = [hashlib.sha256(str(i)).hexdigest() for i in xrange(10000)]

# %%
def pow1(work, _hash):
    '''default with n leading zeros'''
    return _hash.startswith(len(str(work)) * '0')

def pow2(work, _hash):
    '''per byte less than hex value of work'''
    hex_work = hex(work)[2:]
    hex_work_len = 2
    h_prefix = _hash[:hex_work_len]

    return int(h_prefix, 16) > (int(hex_work, 16) / 4)

# %%
work = range(1000)

# %%
pow1_results = [len(filter(lambda h: pow1(i, h), hashes)) for i in work]

# %%
pow2_results = [len(filter(lambda h: pow2(i, h), hashes)) for i in work]

# %%
work = 2
h = "4cf4231"

hex_work = hex(work)[2:]
hex_work_len = len(hex_work)
h_prefix = h[:hex_work_len]

h_prefix, hex_work, int(h_prefix, 16), int(hex_work, 16), int(h_prefix, 16) > int(hex_work, 16),
# Out:
# ('4', '2', 4, 2, True)

# %%
plt.plot(work, pow1_results, color='r')
plt.plot(work, pow2_results, color='b')
# Out:
# <img src="data:image/png;base64,...">

# %%
int('ff', 16)
# Out:
# 1020

# %%
pow1_results
# Out:
# [646,
#  646,
#  646,
#  646,
#  646,
#  646,
#  646,
#  646,
#  646,
#  646,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  38,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
#  4,
# ...
